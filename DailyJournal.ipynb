# %%
import datetime

def view_journal(date):
    try:
        with open("journal.txt", "r") as journal_file:
            lines = journal_file.readlines()
            for line in lines:
                if line.startswith(date):
                    print(line)
    except FileNotFoundError:
        print("No journal entries found.")

def create_journal_entry():
    # Get the current date
    date = datetime.datetime.now().strftime("%Y-%m-%d")

    # Ask the user to input their journal entry
    journal_entry = input("Please enter your journal entry for today: ")

    # Save the date and journal entry into a file
    with open("journal.txt", "a") as journal_file:
        journal_file.write(f"{date}: {journal_entry}\n")

    print("Your journal entry has been saved.")

def main():
    print("Welcome to the Daily Journal Program!")
    print("Please choose an option:")
    print("1. Create a new journal entry")
    print("2. View a previous journal entry")
    print("3. Exit the program")

    while True:
        try:
            choice = int(input("Enter your choice (1-3): "))
        except ValueError:
            print("Invalid input. Please enter a number.")
            continue

        if choice == 1:
            create_journal_entry()
        elif choice == 2:
            date = input("Please enter the date (YYYY-MM-DD): ")
            view_journal(date)
        elif choice == 3:
            print("Goodbye!")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 3.")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Daily Journal Program!
# Please choose an option:
# 1. Create a new journal entry
# 2. View a previous journal entry
# 3. Exit the program
# Enter your choice (1-3): 1
# Please enter your journal entry for today: Today is Thursday November 2023. The climate is cloudy and a bit cold.
# Your journal entry has been saved.
# Enter your choice (1-3): 2
# Please enter the date (YYYY-MM-DD): 2023-11-02
# 2023-11-02: Today is Thursday November 2023. The climate is cloudy and a bit cold.
#
# Enter your choice (1-3): 3
# Goodbye!
